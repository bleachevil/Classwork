# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
import datetime as dt
import pandas as pd

def epochTime(df):
    """ Converts epochTime to datetime format YYYY-MM-DD """
    
    df.drop(columns = ['Unnamed: 0'],inplace=True)
    df['Time'] = df['Time'] / 1000 - 1000
    df['Time'] = pd.to_datetime(df['Time'], unit='s').apply(lambda x: x.strftime('%Y-%m-%d'))
    df.set_index('Time', inplace=True)
    return df

# %%
solana_vol_df = pd.read_csv("Data/solonaVol.csv")
solana_vol_df = epochTime(solana_vol_df)
solana_vol_df
# Out:
#             Solana Volume
# Time
# 2020-04-10   9.267267e+07
# 2020-04-11   4.945869e+07
# 2020-04-12   3.782101e+07
# 2020-04-13   1.957921e+07
# 2020-04-14   1.752353e+07
# ...                   ...
# 2022-04-05   2.136267e+09
# 2022-04-06   3.198016e+09
# 2022-04-07   2.381088e+09
# 2022-04-08   2.314899e+09
# 2022-04-09   1.670543e+09
#
# [730 rows x 1 columns]

# %%
import hvplot.pandas
import matplotlib.pyplot as plt
import plotly.express as px
            
solana_vol_df.index
solvolgraph = solana_vol_df.reset_index()
px.line(data_frame=solvolgraph,x = 'Time',y = 'Solana Volume',color_discrete_sequence = ['red'])
# Out:
# <div>                            <div id="7aec587a-1021-4be1-82e8-b943ce578131" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7aec587a-1021-4be1-82e8-b943ce578131")) {                    Plotly.newPlot(                        "7aec587a-1021-4be1-82e8-b943ce578131",                        [{"hovertemplate":"Time=%{x}<br>Solana Volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28","20
# ...

# %%
bnb_vol_df = pd.read_csv("Data/bnbVol.csv")
bnb_vol_df = epochTime(bnb_vol_df)
bnb_vol_df
# Out:
#             Binance Volume
# Time
# 2020-04-09    3.652217e+08
# 2020-04-10    3.390273e+08
# 2020-04-11    3.790711e+08
# 2020-04-12    4.049799e+08
# 2020-04-13    4.153753e+08
# ...                    ...
# 2022-04-05    2.111671e+09
# 2022-04-06    2.227804e+09
# 2022-04-07    1.902419e+09
# 2022-04-08    1.895965e+09
# 2022-04-09    1.539115e+09
#
# [731 rows x 1 columns]

# %%
bnbvolgraph = bnb_vol_df.reset_index()
px.line(data_frame=bnbvolgraph,x = 'Time',y = 'Binance Volume',color_discrete_sequence = ['blue'])
# Out:
# <div>                            <div id="b9a51005-19da-45b9-bab6-f24a0f171276" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9a51005-19da-45b9-bab6-f24a0f171276")) {                    Plotly.newPlot(                        "b9a51005-19da-45b9-bab6-f24a0f171276",                        [{"hovertemplate":"Time=%{x}<br>Binance Volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"blue","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","
# ...

# %%
cron_vol_df = pd.read_csv("Data/cronVol.csv")
cron_vol_df = epochTime(cron_vol_df)
cron_vol_df
# Out:
#             Cronos Volume
# Time
# 2020-04-09   7.524231e+06
# 2020-04-10   6.586185e+06
# 2020-04-11   6.679442e+06
# 2020-04-12   6.662411e+06
# 2020-04-13   5.896746e+06
# ...                   ...
# 2022-04-05   7.151299e+07
# 2022-04-06   8.810043e+07
# 2022-04-07   6.680808e+07
# 2022-04-08   6.642291e+07
# 2022-04-09   4.898937e+07
#
# [731 rows x 1 columns]

# %%
cronvolgraph = cron_vol_df.reset_index()
px.line(data_frame=cronvolgraph,x = 'Time',y = 'Cronos Volume',color_discrete_sequence = ['green'])
# Out:
# <div>                            <div id="a5f38168-e1ee-441d-b65c-bec6206c10ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5f38168-e1ee-441d-b65c-bec6206c10ed")) {                    Plotly.newPlot(                        "a5f38168-e1ee-441d-b65c-bec6206c10ed",                        [{"hovertemplate":"Time=%{x}<br>Cronos Volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","
# ...

# %%
eth_vol_df = pd.read_csv("Data/ethVol.csv")
eth_vol_df = epochTime(eth_vol_df)
eth_vol_df
# Out:
#             Ethereum Volume
# Time
# 2020-04-09     1.197179e+10
# 2020-04-10     1.413592e+10
# 2020-04-11     1.112899e+10
# 2020-04-12     1.300280e+10
# 2020-04-13     1.328648e+10
# ...                     ...
# 2022-04-05     1.511406e+10
# 2022-04-06     2.610976e+10
# 2022-04-07     1.614978e+10
# 2022-04-08     1.752394e+10
# 2022-04-09     1.250607e+10
#
# [731 rows x 1 columns]

# %%
ethvolgraph = eth_vol_df.reset_index()
px.line(data_frame=ethvolgraph,x = 'Time',y = 'Ethereum Volume',color_discrete_sequence = ['orange'])
# Out:
# <div>                            <div id="35b055e2-aa49-444e-b9ed-84f0942a9faa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35b055e2-aa49-444e-b9ed-84f0942a9faa")) {                    Plotly.newPlot(                        "35b055e2-aa49-444e-b9ed-84f0942a9faa",                        [{"hovertemplate":"Time=%{x}<br>Ethereum Volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"orange","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27
# ...

# %%
fantom_vol_df = pd.read_csv("Data/fantomVol.csv")
fantom_vol_df = epochTime(fantom_vol_df)
fantom_vol_df
# Out:
#             Fantom Volume
# Time
# 2020-04-09   2.173222e+06
# 2020-04-10   2.280835e+06
# 2020-04-11   2.339508e+06
# 2020-04-12   1.684559e+06
# 2020-04-13   1.955905e+06
# ...                   ...
# 2022-04-05   5.501345e+08
# 2022-04-06   9.302908e+08
# 2022-04-07   5.494603e+08
# 2022-04-08   4.576184e+08
# 2022-04-09   3.897682e+08
#
# [731 rows x 1 columns]

# %%
fantomvolgraph = fantom_vol_df.reset_index()
px.line(data_frame=fantomvolgraph,x = 'Time',y = 'Fantom Volume',color_discrete_sequence = ['pink'])
# Out:
# <div>                            <div id="93b4e948-d817-4b0b-9dce-9eda1f1eab98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93b4e948-d817-4b0b-9dce-9eda1f1eab98")) {                    Plotly.newPlot(                        "93b4e948-d817-4b0b-9dce-9eda1f1eab98",                        [{"hovertemplate":"Time=%{x}<br>Fantom Volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"pink","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2
# ...

# %%
poly_vol_df = pd.read_csv("Data/polyVol.csv")
poly_vol_df = epochTime(poly_vol_df)
poly_vol_df
# Out:
#             Polymath Volume
# Time
# 2020-04-09     1.137351e+06
# 2020-04-10     1.974125e+06
# 2020-04-11     1.217371e+06
# 2020-04-12     1.555734e+06
# 2020-04-13     1.867479e+06
# ...                     ...
# 2022-04-05     1.582625e+07
# 2022-04-06     2.655821e+07
# 2022-04-07     1.649691e+07
# 2022-04-08     1.403973e+07
# 2022-04-09     1.332954e+07
#
# [731 rows x 1 columns]

# %%
polyvolgraph = poly_vol_df.reset_index()
px.line(data_frame=polyvolgraph,x = 'Time',y = 'Polymath Volume',color_discrete_sequence = ['maroon'])
# Out:
# <div>                            <div id="8627f92b-600f-4bb0-b74c-0644aa5b40a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8627f92b-600f-4bb0-b74c-0644aa5b40a9")) {                    Plotly.newPlot(                        "8627f92b-600f-4bb0-b74c-0644aa5b40a9",                        [{"hovertemplate":"Time=%{x}<br>Polymath Volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"maroon","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27
# ...

# %%
tron_vol_df = pd.read_csv("Data/tronVol.csv")
tron_vol_df = epochTime(tron_vol_df)
tron_vol_df
# Out:
#              Tron Volume
# Time
# 2020-04-09  1.069727e+09
# 2020-04-10  1.179810e+09
# 2020-04-11  1.101730e+09
# 2020-04-12  1.092810e+09
# 2020-04-13  1.297979e+09
# ...                  ...
# 2022-04-05  1.400060e+09
# 2022-04-06  1.448266e+09
# 2022-04-07  9.209929e+08
# 2022-04-08  8.567597e+08
# 2022-04-09  9.913204e+08
#
# [731 rows x 1 columns]

# %%
tronvolgraph = tron_vol_df.reset_index()
px.line(data_frame=tronvolgraph,x = 'Time',y = 'Tron Volume',color_discrete_sequence = ['magenta'])
# Out:
# <div>                            <div id="6fd7c223-e2a5-4995-af80-56e13388ea00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fd7c223-e2a5-4995-af80-56e13388ea00")) {                    Plotly.newPlot(                        "6fd7c223-e2a5-4995-af80-56e13388ea00",                        [{"hovertemplate":"Time=%{x}<br>Tron Volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"magenta","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","
# ...

# %%
xrp_vol_df = pd.read_csv("Data/XRPVol.csv")
xrp_vol_df = epochTime(xrp_vol_df)
xrp_vol_df
# Out:
#               XRP Volume
# Time
# 2020-04-11  1.781002e+09
# 2020-04-12  2.018968e+09
# 2020-04-13  2.228365e+09
# 2020-04-14  1.862120e+09
# 2020-04-15  1.937689e+09
# ...                  ...
# 2022-04-07  2.580151e+09
# 2022-04-08  2.728014e+09
# 2022-04-09  2.248539e+09
# 2022-04-10  2.353543e+09
# 2022-04-11  3.422791e+09
#
# [731 rows x 1 columns]

# %%
xrpvolgraph = xrp_vol_df.reset_index()
px.line(data_frame=xrpvolgraph,x = 'Time',y = 'XRP Volume',color_discrete_sequence = ['black'])
# Out:
# <div>                            <div id="d4b04500-dc0b-4e64-97e5-3f39028f2a7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4b04500-dc0b-4e64-97e5-3f39028f2a7b")) {                    Plotly.newPlot(                        "d4b04500-dc0b-4e64-97e5-3f39028f2a7b",                        [{"hovertemplate":"Time=%{x}<br>XRP Volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"black","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28","2020-04-29","202
# ...

# %%
all_vol_df = pd.concat([solana_vol_df, bnb_vol_df, cron_vol_df, eth_vol_df, fantom_vol_df, poly_vol_df, tron_vol_df,xrp_vol_df], axis = 1)
all_vol_df.dropna(inplace = True)
all_vol_df
# Out:
#             Solana Volume  Binance Volume  Cronos Volume  Ethereum Volume  \
# Time
# 2020-04-11   4.945869e+07    3.790711e+08   6.679442e+06     1.112899e+10
# 2020-04-12   3.782101e+07    4.049799e+08   6.662411e+06     1.300280e+10
# 2020-04-13   1.957921e+07    4.153753e+08   5.896746e+06     1.328648e+10
# 2020-04-14   1.752353e+07    4.319139e+08   5.457073e+06     1.146843e+10
# 2020-04-15   1.265954e+07    3.933861e+08   5.023388e+06     8.578827e+09
# ...                   ...             ...            ...              ...
# 2022-04-05   2.136267e+09    2.111671e+09   7.151299e+07     1.511406e+10
# 2022-04-06   3.198016e+09    2.227804e+09   8.810043e+07     2.610976e+10
# 2022-04-07   2.381088e+09    1.902419e+09   6.680808e+07     1.614978e+10
# 2022-04-08   2.314899e+09    1.895965e+09   6.642291e+07     1.752394e+10
# 2022-04-09   1.670543e+09    1.539115e+09   4.898937e+07     1.250607e+10
#
#             Fantom Volume  Polymath Volume   Tron Volume    XRP Volume
# ...

# %%
all_vol_df.to_csv("combinedVOL.csv")

# %%
all_vol_df.hvplot.line(xlabel="Time", ylabel=" Volume", dynspread=True).opts(framewise=True)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Time]   (value)

# %%
solana_MC_df = pd.read_csv("Data/solonaMC.csv")
solana_MC_df = epochTime(solana_MC_df)
solana_MC_df
# Out:
#             Solana Market Cap
# Time
# 2020-04-10       7.827652e+06
# 2020-04-11       6.173608e+06
# 2020-04-12       7.269680e+06
# 2020-04-13       6.302364e+06
# 2020-04-14       5.306221e+06
# ...                       ...
# 2022-04-05       4.137492e+10
# 2022-04-06       3.692975e+10
# 2022-04-07       3.889255e+10
# 2022-04-08       3.566301e+10
# 2022-04-09       3.599573e+10
#
# [730 rows x 1 columns]

# %%
solmcgraph = solana_MC_df.reset_index()
px.line(data_frame=solmcgraph,x = 'Time',y = 'Solana Market Cap',color_discrete_sequence = ['red'])
# Out:
# <div>                            <div id="5a8085e5-d9e8-4e5f-849b-7a43d3d19a56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a8085e5-d9e8-4e5f-849b-7a43d3d19a56")) {                    Plotly.newPlot(                        "5a8085e5-d9e8-4e5f-849b-7a43d3d19a56",                        [{"hovertemplate":"Time=%{x}<br>Solana Market Cap=%{y}<extra></extra>","legendgroup":"","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28"
# ...

# %%
bnb_MC_df = pd.read_csv("Data/bnbMC.csv")
bnb_MC_df = epochTime(bnb_MC_df)
bnb_MC_df
# Out:
#             Binance Market Cap
# Time
# 2020-04-09        2.271676e+09
# 2020-04-10        2.073911e+09
# 2020-04-11        2.087482e+09
# 2020-04-12        2.178117e+09
# 2020-04-13        2.272858e+09
# ...                        ...
# 2022-04-05        7.525714e+10
# 2022-04-06        7.091334e+10
# 2022-04-07        7.349142e+10
# 2022-04-08        7.059567e+10
# 2022-04-09        7.128923e+10
#
# [731 rows x 1 columns]

# %%
bnbmcgraph = bnb_MC_df.reset_index()
px.line(data_frame=bnbmcgraph,x = 'Time',y = 'Binance Market Cap',color_discrete_sequence = ['blue'])
# Out:
# <div>                            <div id="ff60cf73-ea0f-4d27-886b-f807cf630951" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff60cf73-ea0f-4d27-886b-f807cf630951")) {                    Plotly.newPlot(                        "ff60cf73-ea0f-4d27-886b-f807cf630951",                        [{"hovertemplate":"Time=%{x}<br>Binance Market Cap=%{y}<extra></extra>","legendgroup":"","line":{"color":"blue","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-2
# ...

# %%
cron_MC_df = pd.read_csv("Data/cronMC.csv")
cron_MC_df = epochTime(cron_MC_df)
cron_MC_df
# Out:
#             Cronos Market Cap
# Time
# 2020-04-09       7.571661e+08
# 2020-04-10       7.040759e+08
# 2020-04-11       7.127033e+08
# 2020-04-12       7.174690e+08
# 2020-04-13       7.087251e+08
# ...                       ...
# 2022-04-05       1.195951e+10
# 2022-04-06       1.116033e+10
# 2022-04-07       1.135962e+10
# 2022-04-08       1.100808e+10
# 2022-04-09       1.104171e+10
#
# [731 rows x 1 columns]

# %%
cronmcgraph = cron_MC_df.reset_index()
px.line(data_frame=cronmcgraph,x = 'Time',y = 'Cronos Market Cap',color_discrete_sequence = ['green'])
# Out:
# <div>                            <div id="d223cdf2-a90f-46b1-916a-f8a164d93cc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d223cdf2-a90f-46b1-916a-f8a164d93cc7")) {                    Plotly.newPlot(                        "d223cdf2-a90f-46b1-916a-f8a164d93cc7",                        [{"hovertemplate":"Time=%{x}<br>Cronos Market Cap=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-2
# ...

# %%
eth_MC_df = pd.read_csv("Data/ethMC.csv")
eth_MC_df = epochTime(eth_MC_df)
eth_MC_df
# Out:
#             Ethereum Market Cap
# Time
# 2020-04-09         1.878745e+10
# 2020-04-10         1.737512e+10
# 2020-04-11         1.748957e+10
# 2020-04-12         1.779041e+10
# 2020-04-13         1.731664e+10
# ...                         ...
# 2022-04-05         4.129449e+11
# 2022-04-06         3.828087e+11
# 2022-04-07         3.888673e+11
# 2022-04-08         3.826629e+11
# 2022-04-09         3.880360e+11
#
# [731 rows x 1 columns]

# %%
ethmcgraph = eth_MC_df.reset_index()
px.line(data_frame=ethmcgraph,x = 'Time',y = 'Ethereum Market Cap',color_discrete_sequence = ['orange'])
# Out:
# <div>                            <div id="f244c3a0-8686-4f57-823d-923a42ce73b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f244c3a0-8686-4f57-823d-923a42ce73b0")) {                    Plotly.newPlot(                        "f244c3a0-8686-4f57-823d-923a42ce73b0",                        [{"hovertemplate":"Time=%{x}<br>Ethereum Market Cap=%{y}<extra></extra>","legendgroup":"","line":{"color":"orange","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-0
# ...

# %%
fantom_MC_df = pd.read_csv("Data/fantomMC.csv")
fantom_MC_df = epochTime(fantom_MC_df)
fantom_MC_df
# Out:
#             Fantom Market Cap
# Time
# 2020-04-09       7.963133e+06
# 2020-04-10       7.010469e+06
# 2020-04-11       7.003354e+06
# 2020-04-12       7.166472e+06
# 2020-04-13       7.273140e+06
# ...                       ...
# 2022-04-05       3.714821e+09
# 2022-04-06       3.325379e+09
# 2022-04-07       3.434371e+09
# 2022-04-08       3.154277e+09
# 2022-04-09       3.211126e+09
#
# [731 rows x 1 columns]

# %%
fantommcgraph = fantom_MC_df.reset_index()
px.line(data_frame=fantommcgraph,x = 'Time',y = 'Fantom Market Cap',color_discrete_sequence = ['pink'])
# Out:
# <div>                            <div id="d8adbf46-0c66-4049-a541-ff410f998cb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8adbf46-0c66-4049-a541-ff410f998cb9")) {                    Plotly.newPlot(                        "d8adbf46-0c66-4049-a541-ff410f998cb9",                        [{"hovertemplate":"Time=%{x}<br>Fantom Market Cap=%{y}<extra></extra>","legendgroup":"","line":{"color":"pink","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27
# ...

# %%
poly_MC_df = pd.read_csv("Data/polyMC.csv")
poly_MC_df = epochTime(poly_MC_df)
poly_MC_df
# Out:
#             Polymath Market Cap
# Time
# 2020-04-09         1.267565e+07
# 2020-04-10         1.160580e+07
# 2020-04-11         1.145650e+07
# 2020-04-12         1.175888e+07
# 2020-04-13         1.127164e+07
# ...                         ...
# 2022-04-05         4.377498e+08
# 2022-04-06         3.860890e+08
# 2022-04-07         3.989134e+08
# 2022-04-08         3.818549e+08
# 2022-04-09         3.857708e+08
#
# [731 rows x 1 columns]

# %%
polymcgraph = poly_MC_df.reset_index()
px.line(data_frame=polymcgraph,x = 'Time',y = 'Polymath Market Cap',color_discrete_sequence = ['maroon'])
# Out:
# <div>                            <div id="ffad1637-fbaf-4efc-9fdd-1493654fd35d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffad1637-fbaf-4efc-9fdd-1493654fd35d")) {                    Plotly.newPlot(                        "ffad1637-fbaf-4efc-9fdd-1493654fd35d",                        [{"hovertemplate":"Time=%{x}<br>Polymath Market Cap=%{y}<extra></extra>","legendgroup":"","line":{"color":"maroon","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-0
# ...

# %%
tron_MC_df = pd.read_csv("Data/tronMC.csv")
tron_MC_df = epochTime(tron_MC_df)
tron_MC_df
# Out:
#             Tron Market Cap
# Time
# 2020-04-09     8.898568e+08
# 2020-04-10     8.220813e+08
# 2020-04-11     8.257288e+08
# 2020-04-12     8.488375e+08
# 2020-04-13     8.377505e+08
# ...                     ...
# 2022-04-05     7.069255e+09
# 2022-04-06     6.436734e+09
# 2022-04-07     6.562939e+09
# 2022-04-08     6.342604e+09
# 2022-04-09     6.360527e+09
#
# [731 rows x 1 columns]

# %%
tronmcgraph = tron_MC_df.reset_index()
px.line(data_frame=tronmcgraph,x = 'Time',y = 'Tron Market Cap',color_discrete_sequence = ['magenta'])
# Out:
# <div>                            <div id="67137503-dcc7-4d2e-b51a-e53dda67cea6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67137503-dcc7-4d2e-b51a-e53dda67cea6")) {                    Plotly.newPlot(                        "67137503-dcc7-4d2e-b51a-e53dda67cea6",                        [{"hovertemplate":"Time=%{x}<br>Tron Market Cap=%{y}<extra></extra>","legendgroup":"","line":{"color":"magenta","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-2
# ...

# %%
xrp_MC_df = pd.read_csv("Data/XRPMC.csv")
xrp_MC_df = epochTime(xrp_MC_df)
xrp_MC_df
# Out:
#             XRP Market Cap
# Time
# 2020-04-11    8.293802e+09
# 2020-04-12    8.265151e+09
# 2020-04-13    8.299612e+09
# 2020-04-14    8.202410e+09
# 2020-04-15    8.011762e+09
# ...                    ...
# 2022-04-07    3.794499e+10
# 2022-04-08    3.622297e+10
# 2022-04-09    3.674412e+10
# 2022-04-10    3.640362e+10
# 2022-04-11    3.375855e+10
#
# [731 rows x 1 columns]

# %%
xrpmcgraph = xrp_MC_df.reset_index()
px.line(data_frame=xrpmcgraph,x = 'Time',y = 'XRP Market Cap',color_discrete_sequence = ['black'])
# Out:
# <div>                            <div id="5b076f93-2117-4196-a8f9-c73c0f7a77bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b076f93-2117-4196-a8f9-c73c0f7a77bd")) {                    Plotly.newPlot(                        "5b076f93-2117-4196-a8f9-c73c0f7a77bd",                        [{"hovertemplate":"Time=%{x}<br>XRP Market Cap=%{y}<extra></extra>","legendgroup":"","line":{"color":"black","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28","2020-04-29",
# ...

# %%
all_MC_df = pd.concat([solana_MC_df, bnb_MC_df, cron_MC_df, eth_MC_df, fantom_MC_df, poly_MC_df, tron_MC_df,xrp_MC_df], axis = 1)
all_MC_df.dropna(inplace = True)
all_MC_df
# Out:
#             Solana Market Cap  Binance Market Cap  Cronos Market Cap  \
# Time
# 2020-04-11       6.173608e+06        2.087482e+09       7.127033e+08
# 2020-04-12       7.269680e+06        2.178117e+09       7.174690e+08
# 2020-04-13       6.302364e+06        2.272858e+09       7.087251e+08
# 2020-04-14       5.306221e+06        2.357467e+09       7.124800e+08
# 2020-04-15       5.114654e+06        2.207840e+09       6.867414e+08
# ...                       ...                 ...                ...
# 2022-04-05       4.137492e+10        7.525714e+10       1.195951e+10
# 2022-04-06       3.692975e+10        7.091334e+10       1.116033e+10
# 2022-04-07       3.889255e+10        7.349142e+10       1.135962e+10
# 2022-04-08       3.566301e+10        7.059567e+10       1.100808e+10
# 2022-04-09       3.599573e+10        7.128923e+10       1.104171e+10
#
#             Ethereum Market Cap  Fantom Market Cap  Polymath Market Cap  \
# Time
# ...

# %%
all_MC_df.to_csv("combinedMC.csv")

# %%
all_MC_df.hvplot.line(xlabel="Time", ylabel=" Market Cap", dynspread=True).opts(framewise=True)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Time]   (value)

# %%
all_MC_df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
all_vol_df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Time'>
