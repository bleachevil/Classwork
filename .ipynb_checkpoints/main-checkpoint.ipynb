# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import ratio as r
import helper_functions as hf

# %%
solana_price_df = pd.read_csv("Data/solona.csv")
solana_price_df = hf.epochTime(solana_price_df)
solana_price_df
# Out:
#             Solana Price
# Time
# 2020-04-10      0.957606
# 2020-04-11      0.784711
# 2020-04-12      0.875994
# 2020-04-13      0.786712
# 2020-04-14      0.666673
# ...                  ...
# 2022-04-05    126.605680
# 2022-04-06    112.529026
# 2022-04-07    118.688395
# 2022-04-08    109.691488
# 2022-04-09    110.632802
#
# [730 rows x 1 columns]

# %%
aval_price_df = pd.read_csv("Data/aval.csv")
aval_price_df = hf.epochTime(aval_price_df)
aval_price_df
# Out:
#             Avalanche Price
# Time
# 2020-09-21         5.284244
# 2020-09-22         5.284244
# 2020-09-23         3.491229
# 2020-09-24         4.573891
# 2020-09-25         4.702974
# ...                     ...
# 2022-04-05        91.092547
# 2022-04-06        82.886209
# 2022-04-07        87.955600
# 2022-04-08        83.715830
# 2022-04-09        82.894434
#
# [566 rows x 1 columns]

# %%
bnb_price_df = pd.read_csv("Data/bnb.csv")
bnb_price_df = hf.epochTime(bnb_price_df)
bnb_price_df
# Out:
#             Binance Price
# Time
# 2020-04-09      15.028759
# 2020-04-10      13.718826
# 2020-04-11      13.826759
# 2020-04-12      14.265117
# 2020-04-13      15.045573
# ...                   ...
# 2022-04-05     446.692828
# 2022-04-06     420.521418
# 2022-04-07     437.092422
# 2022-04-08     421.468652
# 2022-04-09     423.415557
#
# [731 rows x 1 columns]

# %%
bnb_price_df = pd.read_csv("Data/cron.csv")
bnb_price_df = hf.epochTime(bnb_price_df)
bnb_price_df
# Out:
#             Cronos Price
# Time
# 2020-04-09      0.053171
# 2020-04-10      0.049563
# 2020-04-11      0.050024
# 2020-04-12      0.050062
# 2020-04-13      0.049767
# ...                  ...
# 2022-04-05      0.471989
# 2022-04-06      0.440632
# 2022-04-07      0.448653
# 2022-04-08      0.436403
# 2022-04-09      0.437563
#
# [731 rows x 1 columns]

# %%
eth_price_df = pd.read_csv("Data/eth.csv")
eth_price_df = hf.epochTime(eth_price_df)
eth_price_df
# Out:
#             Ethereum Price
# Time
# 2020-04-09      170.095104
# 2020-04-10      157.740158
# 2020-04-11      158.327878
# 2020-04-12      158.863826
# 2020-04-13      156.701359
# ...                    ...
# 2022-04-05     3422.969884
# 2022-04-06     3171.371104
# 2022-04-07     3232.834989
# 2022-04-08     3192.025091
# 2022-04-09     3226.579728
#
# [731 rows x 1 columns]

# %%
fantom_price_df = pd.read_csv("Data/fantom.csv")
fantom_price_df = hf.epochTime(fantom_price_df)
fantom_price_df
# Out:
#             Fantom Price
# Time
# 2020-04-09      0.003793
# 2020-04-10      0.003307
# 2020-04-11      0.003309
# 2020-04-12      0.003374
# 2020-04-13      0.003414
# ...                  ...
# 2022-04-05      1.454651
# 2022-04-06      1.303942
# 2022-04-07      1.350759
# 2022-04-08      1.245745
# 2022-04-09      1.263165
#
# [731 rows x 1 columns]

# %%
poly_price_df = pd.read_csv("Data/poly.csv")
poly_price_df = hf.epochTime(poly_price_df)
poly_price_df
# Out:
#             PolyMath Price
# Time
# 2020-04-09        0.020419
# 2020-04-10        0.018715
# 2020-04-11        0.018466
# 2020-04-12        0.018751
# 2020-04-13        0.018010
# ...                    ...
# 2022-04-05        0.485305
# 2022-04-06        0.426554
# 2022-04-07        0.443645
# 2022-04-08        0.426783
# 2022-04-09        0.427720
#
# [731 rows x 1 columns]

# %%
tron_price_df = pd.read_csv("Data/tron.csv")
tron_price_df = hf.epochTime(tron_price_df)
tron_price_df
# Out:
#             Tron Price
# Time
# 2020-04-09    0.013435
# 2020-04-10    0.012504
# 2020-04-11    0.012500
# 2020-04-12    0.012708
# 2020-04-13    0.012576
# ...                ...
# 2022-04-05    0.069441
# 2022-04-06    0.063205
# 2022-04-07    0.064453
# 2022-04-08    0.062606
# 2022-04-09    0.062542
#
# [731 rows x 1 columns]

# %%
cronos_price_df = pd.read_csv("Data/cron.csv")
cronos_price_df = hf.epochTime(cronos_price_df)
cronos_price_df
# Out:
#             Cronos Price
# Time
# 2020-04-09      0.053171
# 2020-04-10      0.049563
# 2020-04-11      0.050024
# 2020-04-12      0.050062
# 2020-04-13      0.049767
# ...                  ...
# 2022-04-05      0.471989
# 2022-04-06      0.440632
# 2022-04-07      0.448653
# 2022-04-08      0.436403
# 2022-04-09      0.437563
#
# [731 rows x 1 columns]

# %%
# all_coins_df = pd.concat([solana_price_df, aval_price_df, tron_price_df, poly_price_df, 
#                           fantom_price_df, eth_price_df, cronos_price_df, bnb_price_df], axis = 1)

# removed aval since it doesn't have 2 years of data
all_coins_df = pd.concat([solana_price_df, tron_price_df, poly_price_df, fantom_price_df, eth_price_df, cronos_price_df, bnb_price_df], axis = 1)
all_coins_df.dropna(inplace = True)
all_coins_df
# Out:
#             Solana Price  Tron Price  PolyMath Price  Fantom Price  \
# Time
# 2020-04-10      0.957606    0.012504        0.018715      0.003307
# 2020-04-11      0.784711    0.012500        0.018466      0.003309
# 2020-04-12      0.875994    0.012708        0.018751      0.003374
# 2020-04-13      0.786712    0.012576        0.018010      0.003414
# 2020-04-14      0.666673    0.012420        0.018902      0.003211
# ...                  ...         ...             ...           ...
# 2022-04-05    126.605680    0.069441        0.485305      1.454651
# 2022-04-06    112.529026    0.063205        0.426554      1.303942
# 2022-04-07    118.688395    0.064453        0.443645      1.350759
# 2022-04-08    109.691488    0.062606        0.426783      1.245745
# 2022-04-09    110.632802    0.062542        0.427720      1.263165
#
#             Ethereum Price  Cronos Price  Cronos Price
# Time
# 2020-04-10      157.740158      0.049563      0.049563
# 2020-04-11      158.327878      0.050024      0.050024
# 2020-04-12      158.863826      0.050062      0.050062
# 2020-04-13      156.701359      0.049767      0.049767
# 2020-04-14      158.267151      0.050093      0.050093
# ...                    ...           ...           ...
# 2022-04-05     3422.969884      0.471989      0.471989
# 2022-04-06     3171.371104      0.440632      0.440632
# 2022-04-07     3232.834989      0.448653      0.448653
# 2022-04-08     3192.025091      0.436403      0.436403
# 2022-04-09     3226.579728      0.437563      0.437563
#
# [730 rows x 7 columns]

# %%
r.markowitz(all_coins_df)
